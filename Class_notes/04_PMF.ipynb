# %%
#Plot functions:
#Probability mass function
#Quantile-Quantile Plots
#Empirical cumulative distribution function

#Dane:
#csv
#wczytaj prawiodłowo datę
#ustaw na tej kolumnie index (wszystko w trakcie wczytywania)

#To do:
#histogramy, PMF, QQ ploty(wykonaj na końcu) dla róznej liczby pokoi vs cena:
#wybierz reprezentatywne przedziały (np. sprawdź ile jest mieszkań dla danej liczby pokoi)
#utwórz np. 3 przedziały => np. 3 pd.DataFrame
#wszystkie ploty danego typu muszą być na jednym wykresie, czyli np 3 histogramy na jednym wykresie,

#Tips & hints:
#sprawdź możliwe "typy" histogramów, np. step , stack , poly
#aby utworzyć QQ ploty zobacz tu, tu lub tu
#https://www.statsmodels.org/devel/generated/statsmodels.graphics.gofplots.qqplot.html
#https://seaborn-qqplot.readthedocs.io/en/latest/
#https://www.geeksforgeeks.org/qqplot-quantile-quantile-plot-in-python/

# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv('houses_data.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data["Month"] = data.index.month

data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
rooms_2 = data[data["Rooms"]==2]
rooms_3 = data[data["Rooms"]==3]
rooms_4 = data[data["Rooms"]==4]
rooms_5 = data[data["Rooms"]==5]
rooms_6 = data[data["Rooms"]==6]
rooms_7 = data[data["Rooms"]==7]
rooms_8 = data[data["Rooms"]==8]
rooms_9 = data[data["Rooms"]==9]
rooms_10 = data[data["Rooms"]==10]



sns.histplot(rooms_2, x="Price", bins = 60)
sns.histplot(rooms_3, x="Price", bins = 60)
sns.histplot(rooms_4, x="Price", bins = 60)
sns.histplot(rooms_5, x="Price", bins = 60)
sns.histplot(rooms_6, x="Price", bins = 60)
sns.histplot(rooms_7, x="Price", bins = 60)
sns.histplot(rooms_8, x="Price", bins = 60)
sns.histplot(rooms_9, x="Price", bins = 60)
sns.histplot(rooms_10, x="Price", bins = 60)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 7))


sns.histplot(data=data, x="Price",hue="Rooms",element='step', ax=axs[0], palette="Greens_r")
sns.histplot(data=data, x="Price",hue="Bathroom",element='bars', ax=axs[1], palette="Reds_r")
sns.histplot(data=data, x="Price",hue="Car",element='poly', ax=axs[2], palette="Blues_r")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price",hue="Rooms",element='bars')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import numpy as np

n, bins, patches = plt.hist(data=data, x=['Rooms'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 10.0)
